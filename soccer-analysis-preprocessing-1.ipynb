# %%
import sqlite3
import pandas as pd
import numpy as np

from datetime import datetime
from dateutil.relativedelta import relativedelta

from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

import matplotlib.pyplot as plt 
import seaborn as sns # Import seaborn

from datetime import datetime
from datetime import date
from dateutil import parser

from collections import defaultdict

import warnings
import time

# %% [markdown]
# ## Acquire data
#
# Our data comes from a database file in SQLite format. We import it into a Pandas DataFrame for preprocessing.

# %%
# open connection 
conn = sqlite3.connect("data/database.sqlite")
cur = conn.cursor()

# %%
# function to execute queries
def executeQuery(cur, query):
    print("executing query: ")
    cur.execute(query)
    return cur.fetchall()

# %%
# list of all tables
q_all_tables = """SELECT name FROM sqlite_master
    WHERE type='table';"""
all_tables = executeQuery(cur, q_all_tables)
# Out:
# executing query:

# %%
# read the Match table into Pandas DataFrame
q_matches = "SELECT * FROM MATCH;"
df_matches = pd.read_sql_query(q_matches, conn)

# %% [markdown]
# ### Preprocessing Data
# - we are dropping the columns that will not be needed for preliminary analysis

# %%
# do this only 1
# drop betting
df_matches = df_matches.drop(df_matches.iloc[:, 85:], axis=1)

#drop statistics
df_matches = df_matches.drop(df_matches.iloc[:, 77:], axis=1)
print(df_matches.info())
# drop X, Y positions
df_matches = df_matches.drop(df_matches.iloc[:, 11:55], axis=1)

# drop fifa_api_id and a couple other columns irrelevant
df_matches = df_matches.drop(df_matches.columns[[1, 2, 4]], axis=1)
print(df_matches.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25979 entries, 0 to 25978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                25979 non-null  int64
#  1   country_id        25979 non-null  int64
#  2   league_id         25979 non-null  int64
#  3   season            25979 non-null  object
#  4   stage             25979 non-null  int64
#  5   date              25979 non-null  object
#  6   match_api_id      25979 non-null  int64
#  7   home_team_api_id  25979 non-null  int64
#  8   away_team_api_id  25979 non-null  int64
#  9   home_team_goal    25979 non-null  int64
#  10  away_team_goal    25979 non-null  int64
#  11  home_player_X1    24158 non-null  float64
#  12  home_player_X2    24158 non-null  float64
#  13  home_player_X3    24147 non-null  float64
#  14  home_player_X4    24147 non-null  float64
#  15  home_player_X5    24147 non-null  float64
#  16  home_player_X6    24147 non-null  float64
#  17  home_player_X7    24147 non-null  float64
#  18  home_player_X8    24147 non-null  float64
#  19  home_player_X9    24147 non-null  float64
#  20  home_player_X10   24147 non-null  float64
#  21  home_player_X11   24147 non-null  float64
#  22  away_player_X1    24147 non-null  float64
#  23  away_player_X2    24147 non-null  float64
#  24  away_player_X3    24147 non-null  float64
#  25  away_player_X4    24147 non-null  float64
#  26  away_player_X5    24147 non-null  float64
#  27  away_player_X6    24147 non-null  float64
#  28  away_player_X7    24147 non-null  float64
#  29  away_player_X8    24147 non-null  float64
#  30  away_player_X9    24146 non-null  float64
#  31  away_player_X10   24146 non-null  float64
#  32  away_player_X11   24140 non-null  float64
#  33  home_player_Y1    24158 non-null  float64
#  34  home_player_Y2    24158 non-null  float64
#  35  home_player_Y3    24147 non-null  float64
#  36  home_player_Y4    24147 non-null  float64
#  37  home_player_Y5    24147 non-null  float64
#  38  home_player_Y6    24147 non-null  float64
#  39  home_player_Y7    24147 non-null  float64
#  40  home_player_Y8    24147 non-null  float64
#  41  home_player_Y9    24147 non-null  float64
#  42  home_player_Y10   24147 non-null  float64
#  43  home_player_Y11   24147 non-null  float64
#  44  away_player_Y1    24147 non-null  float64
#  45  away_player_Y2    24147 non-null  float64
#  46  away_player_Y3    24147 non-null  float64
#  47  away_player_Y4    24147 non-null  float64
#  48  away_player_Y5    24147 non-null  float64
#  49  away_player_Y6    24147 non-null  float64
#  50  away_player_Y7    24147 non-null  float64
#  51  away_player_Y8    24147 non-null  float64
#  52  away_player_Y9    24146 non-null  float64
#  53  away_player_Y10   24146 non-null  float64
#  54  away_player_Y11   24140 non-null  float64
#  55  home_player_1     24755 non-null  float64
#  56  home_player_2     24664 non-null  float64
#  57  home_player_3     24698 non-null  float64
#  58  home_player_4     24656 non-null  float64
#  59  home_player_5     24663 non-null  float64
#  60  home_player_6     24654 non-null  float64
#  61  home_player_7     24752 non-null  float64
#  62  home_player_8     24670 non-null  float64
#  63  home_player_9     24706 non-null  float64
#  64  home_player_10    24543 non-null  float64
#  65  home_player_11    24424 non-null  float64
#  66  away_player_1     24745 non-null  float64
#  67  away_player_2     24701 non-null  float64
#  68  away_player_3     24686 non-null  float64
#  69  away_player_4     24658 non-null  float64
#  70  away_player_5     24644 non-null  float64
#  71  away_player_6     24666 non-null  float64
#  72  away_player_7     24744 non-null  float64
#  73  away_player_8     24638 non-null  float64
#  74  away_player_9     24651 non-null  float64
#  75  away_player_10    24538 non-null  float64
#  76  away_player_11    24425 non-null  float64
# dtypes: float64(66), int64(9), object(2)
# memory usage: 15.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25979 entries, 0 to 25978
# Data columns (total 30 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                25979 non-null  int64
#  1   season            25979 non-null  object
#  2   date              25979 non-null  object
#  3   match_api_id      25979 non-null  int64
#  4   home_team_api_id  25979 non-null  int64
#  5   away_team_api_id  25979 non-null  int64
#  6   home_team_goal    25979 non-null  int64
#  7   away_team_goal    25979 non-null  int64
#  8   home_player_1     24755 non-null  float64
#  9   home_player_2     24664 non-null  float64
#  10  home_player_3     24698 non-null  float64
#  11  home_player_4     24656 non-null  float64
#  12  home_player_5     24663 non-null  float64
#  13  home_player_6     24654 non-null  float64
#  14  home_player_7     24752 non-null  float64
#  15  home_player_8     24670 non-null  float64
#  16  home_player_9     24706 non-null  float64
#  17  home_player_10    24543 non-null  float64
#  18  home_player_11    24424 non-null  float64
#  19  away_player_1     24745 non-null  float64
#  20  away_player_2     24701 non-null  float64
#  21  away_player_3     24686 non-null  float64
#  22  away_player_4     24658 non-null  float64
#  23  away_player_5     24644 non-null  float64
#  24  away_player_6     24666 non-null  float64
#  25  away_player_7     24744 non-null  float64
#  26  away_player_8     24638 non-null  float64
#  27  away_player_9     24651 non-null  float64
#  28  away_player_10    24538 non-null  float64
#  29  away_player_11    24425 non-null  float64
# dtypes: float64(22), int64(6), object(2)
# memory usage: 5.9+ MB
# None

# %%
df_matches.head()
# print(df_matches.shape)
# Out:
#    id     season                 date  match_api_id  home_team_api_id  \
# 0   1  2008/2009  2008-08-17 00:00:00        492473              9987
# 1   2  2008/2009  2008-08-16 00:00:00        492474             10000
# 2   3  2008/2009  2008-08-16 00:00:00        492475              9984
# 3   4  2008/2009  2008-08-17 00:00:00        492476              9991
# 4   5  2008/2009  2008-08-16 00:00:00        492477              7947
#
#    away_team_api_id  home_team_goal  away_team_goal  home_player_1  \
# 0              9993               1               1            NaN
# 1              9994               0               0            NaN
# 2              8635               0               3            NaN
# 3              9998               5               0            NaN
# 4              9985               1               3            NaN
#
#    home_player_2  ...  away_player_2  away_player_3  away_player_4  \
# 0            NaN  ...            NaN            NaN            NaN
# 1            NaN  ...            NaN            NaN            NaN
# 2            NaN  ...            NaN            NaN            NaN
# 3            NaN  ...            NaN            NaN            NaN
# 4            NaN  ...            NaN            NaN            NaN
#
#    away_player_5  away_player_6  away_player_7  away_player_8  away_player_9  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    away_player_10  away_player_11
# 0             NaN             NaN
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN             NaN
#
# [5 rows x 30 columns]

# %%
# Drop player_fifa_api_id from player table
# read the Match table into Pandas DataFrame
q_player = "SELECT * FROM PLAYER;"
df_player = pd.read_sql_query(q_player, conn)

print(df_player.shape)
# df_player = df_player.set_index('player_api_id')
df_player = df_player.drop(['player_fifa_api_id', 'id'], axis=1)
print(df_player.shape)
df_player.tail()
# Out:
# (11060, 7)
# (11060, 5)
#        player_api_id          player_name             birthday  height  weight
# 11055          26357       Zoumana Camara  1979-04-03 00:00:00  182.88     168
# 11056         111182         Zsolt Laczko  1986-12-18 00:00:00  182.88     176
# 11057          36491            Zsolt Low  1979-04-29 00:00:00  180.34     154
# 11058          35506  Zurab Khizanishvili  1981-10-06 00:00:00  185.42     172
# 11059          39902   Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176

# %%
# import data from player attribute table

q_player_attr = "SELECT * FROM Player_Attributes;"
df_player_attr = pd.read_sql_query(q_player_attr, conn)

print(df_player_attr.shape)
df_player_attr = df_player_attr.loc[:, [ 'player_api_id', 'date', 'overall_rating']]

dict_player_attr = defaultdict(dict)
for index, row in df_player_attr.iterrows():
    dict_player_attr[row['player_api_id']][row['date']] = row['overall_rating']

print(len(dict_player_attr))
print(dict_player_attr[39902])
print(df_player_attr['player_api_id'].nunique())
# Out:
# (183978, 42)
# 11060
# {'2012-08-31 00:00:00': 78.0, '2012-02-22 00:00:00': 81.0, '2011-08-30 00:00:00': 81.0, '2011-02-22 00:00:00': 81.0, '2010-08-30 00:00:00': 83.0, '2009-08-30 00:00:00': 83.0, '2009-02-22 00:00:00': 78.0, '2008-08-30 00:00:00': 77.0, '2007-08-30 00:00:00': 78.0, '2007-02-22 00:00:00': 80.0}
# 11060

# %%
def mostRecentRating(dates_dict, given_date_str):
    given_date = parser.parse(given_date_str).date()
    dates_dict_dt = {parser.parse(date_str).date(): value for date_str, value in dates_dict.items()}
    smaller_dates = {date: value for date, value in dates_dict_dt.items() if date <= given_date}
    highest_date = max(smaller_dates.keys())
    return dates_dict_dt[highest_date]

dates_list = ['2022-01-01', '2022-01-05', '2022-01-15', '2022-01-15', '2022-01-20', '2022-01-11']
dates_ratings = [80, 89, 32, 45, 11, 33]

all_dates = dict(zip(dates_list, dates_ratings))
# given date
given_date_str = '2022-01-12'
# print(all_dates)
# print(mostRecentRating(all_dates, given_date_str))
# print(mostRecentRating(dict_player_attr[39902], '2009-02-21'))

# %%
print(df_player.shape)

print(df_player.tail())
print(df_player.shape)
# Out:
# (11060, 5)
#        player_api_id          player_name             birthday  height  weight
# 11055          26357       Zoumana Camara  1979-04-03 00:00:00  182.88     168
# 11056         111182         Zsolt Laczko  1986-12-18 00:00:00  182.88     176
# 11057          36491            Zsolt Low  1979-04-29 00:00:00  180.34     154
# 11058          35506  Zurab Khizanishvili  1981-10-06 00:00:00  185.42     172
# 11059          39902   Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# (11060, 5)

# %%
# import team name
q_team = "SELECT * FROM Team"
df_team = pd.read_sql_query(q_team, conn)
df_team = df_team.loc[:, ['team_api_id', 'team_long_name', 'team_short_name']]

df_team.tail(10)
# Out:
#      team_api_id      team_long_name team_short_name
# 289        10179             FC Sion             SIO
# 290        10199           FC Luzern             LUZ
# 291         9824            FC Vaduz             VAD
# 292         7955     Neuchâtel Xamax             XAM
# 293        10243           FC Zürich             ZUR
# 294        10190       FC St. Gallen             GAL
# 295        10191             FC Thun             THU
# 296         9777         Servette FC             SER
# 297         7730  FC Lausanne-Sports             LAU
# 298         7896              Lugano             LUG

# %%
# import Country but wont use them they dont add value to the model
q_country = "SELECT * FROM Country"
df_country = pd.read_sql_query(q_country, conn)
df_country.tail()
# Out:
#        id         name
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland

# %%
# import League but wont use them they dont add value to the model
q_league = "SELECT * FROM League"
df_league = pd.read_sql_query(q_league, conn)
df_league.tail()
# Out:
#        id  country_id                      name
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League

# %%
# import Team_Attributes but wont use them they dont add value to the model
q_team_attr = "SELECT * FROM Team_Attributes"
df_team_attr = pd.read_sql_query(q_team_attr, conn)
df_team_attr.tail()
# Out:
#         id  team_fifa_api_id  team_api_id                 date  \
# 1453  1454             15005        10000  2011-02-22 00:00:00
# 1454  1455             15005        10000  2012-02-22 00:00:00
# 1455  1456             15005        10000  2013-09-20 00:00:00
# 1456  1457             15005        10000  2014-09-19 00:00:00
# 1457  1458             15005        10000  2015-09-10 00:00:00
#
#       buildUpPlaySpeed buildUpPlaySpeedClass  buildUpPlayDribbling  \
# 1453                52              Balanced                   NaN
# 1454                54              Balanced                   NaN
# 1455                54              Balanced                   NaN
# 1456                54              Balanced                  42.0
# 1457                54              Balanced                  42.0
#
#      buildUpPlayDribblingClass  buildUpPlayPassing buildUpPlayPassingClass  \
# 1453                    Little                  52                   Mixed
# 1454                    Little                  51                   Mixed
# 1455                    Little                  51                   Mixed
# 1456                    Normal                  51                   Mixed
# 1457                    Normal                  51                   Mixed
#
#       ... chanceCreationShooting  chanceCreationShootingClass  \
# 1453  ...                     53                       Normal
# 1454  ...                     50                       Normal
# 1455  ...                     32                       Little
# 1456  ...                     32                       Little
# 1457  ...                     32                       Little
#
#      chanceCreationPositioningClass  defencePressure defencePressureClass  \
# 1453                      Organised               46               Medium
# 1454                      Organised               44               Medium
# 1455                      Organised               44               Medium
# 1456                      Organised               44               Medium
# 1457                      Organised               44               Medium
#
#       defenceAggression defenceAggressionClass defenceTeamWidth  \
# 1453                 48                  Press               53
# 1454                 55                  Press               53
# 1455                 58                  Press               37
# 1456                 58                  Press               37
# 1457                 58                  Press               37
#
#       defenceTeamWidthClass defenceDefenderLineClass
# 1453                 Normal                    Cover
# 1454                 Normal                    Cover
# 1455                 Normal                    Cover
# 1456                 Normal                    Cover
# 1457                 Normal                    Cover
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Consolidating features from Matches, Players, and other dataframes into a single DF
# This is the basis for model building

# %%
df_main = df_matches
df_main.tail()
# Out:
#           id     season                 date  match_api_id  home_team_api_id  \
# 25974  25975  2015/2016  2015-09-22 00:00:00       1992091             10190
# 25975  25976  2015/2016  2015-09-23 00:00:00       1992092              9824
# 25976  25977  2015/2016  2015-09-23 00:00:00       1992093              9956
# 25977  25978  2015/2016  2015-09-22 00:00:00       1992094              7896
# 25978  25979  2015/2016  2015-09-23 00:00:00       1992095             10192
#
#        away_team_api_id  home_team_goal  away_team_goal  home_player_1  \
# 25974             10191               1               0        42231.0
# 25975             10199               1               2        33272.0
# 25976             10179               2               0       157856.0
# 25977             10243               0               0            NaN
# 25978              9931               4               3       274787.0
#
#        home_player_2  ...  away_player_2  away_player_3  away_player_4  \
# 25974       678384.0  ...       563066.0         8800.0        67304.0
# 25975        41621.0  ...       114792.0       150007.0       178119.0
# 25976       274779.0  ...        67349.0       202663.0        32597.0
# 25977         8881.0  ...       121080.0       197757.0       260964.0
# 25978       492132.0  ...        95216.0       172768.0        22834.0
#
#        away_player_5  away_player_6  away_player_7  away_player_8  \
# 25974       158253.0       133126.0       186524.0        93223.0
# 25975        27232.0       570830.0       260708.0       201704.0
# 25976       114794.0       188114.0        25840.0       482200.0
# 25977       231614.0       113235.0        41116.0       462608.0
# 25978       458806.0       207234.0        25772.0        40274.0
#
#        away_player_9  away_player_10  away_player_11
# 25974       121115.0        232110.0        289732.0
# 25975        36382.0         34082.0         95257.0
# 25976        95230.0        451335.0        275122.0
# 25977        42262.0         92252.0        194532.0
# 25978        34035.0         41726.0        527103.0
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Feb 22, Join player name into main_df

# %%
print(df_main.shape)
# Out:
# (25979, 30)

# %%
# NB RUN THIS CODE ONLY ONCE or restart needed
pd.options.mode.chained_assignment = None

df_main = df_main.rename(columns={"id":"id_main"})
df_player = df_player.rename(columns={"id":"id_player"})

# %%
hp = 'home_player_'
for i in range(1, 12):
    hp_n = hp+str(i)
    df_main = df_main.merge(df_player, left_on=hp_n, right_on="player_api_id")
    df_main = df_main.rename(columns={"id_player": hp_n+"_id", "player_name": hp_n+"_name", "birthday": hp_n+"_birthday", "height":hp_n+"_height", "weight":hp_n+"_weight"})
    
ap = 'away_player_'
for i in range(1, 12):
    ap_n = ap+str(i)
    df_main = df_main.merge(df_player, left_on=ap_n, right_on="player_api_id")
    df_main = df_main.rename(columns={"id_player": ap_n+"_id", "player_name": ap_n+"_name", "birthday": ap_n+"_birthday", "height":ap_n+"_height", "weight":ap_n+"_weight"})
df_main.drop(['player_api_id_x', 'player_api_id_y'], axis=1)
# print(df_main.tail())
# Out:
# /var/folders/nz/yzml0f156sl47_8h6p_8gwc40000gn/T/ipykernel_21626/3440392743.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'player_api_id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_main = df_main.merge(df_player, left_on=hp_n, right_on="player_api_id")
# /var/folders/nz/yzml0f156sl47_8h6p_8gwc40000gn/T/ipykernel_21626/3440392743.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'player_api_id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_main = df_main.merge(df_player, left_on=hp_n, right_on="player_api_id")
# /var/folders/nz/yzml0f156sl47_8h6p_8gwc40000gn/T/ipykernel_21626/3440392743.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'player_api_id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_main = df_main.merge(df_player, left_on=hp_n, right_on="player_api_id")
# /var/folders/nz/yzml0f156sl47_8h6p_8gwc40000gn/T/ipykernel_21626/3440392743.py:4: FutureWarning: Passing 'suffixes' which cause duplicate columns {'player_api_id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_main = df_main.merge(df_player, left_on=hp_n, right_on="player_api_id")
# /var/folders/nz/yzml0f156sl47_8h6p_8gwc40000gn/T/ipykernel_21626/3440392743.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'player_api_id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_main = df_main.merge(df_player, left_on=ap_n, right_on="player_api_id")
# /var/folders/nz/yzml0f156sl47_8h6p_8gwc40000gn/T/ipykernel_21626/3440392743.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'player_api_id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_main = df_main.merge(df_player, left_on=ap_n, right_on="player_api_id")
# /var/folders/nz/yzml0f156sl47_8h6p_8gwc40000gn/T/ipykernel_21626/3440392743.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'player_api_id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_main = df_main.merge(df_player, left_on=ap_n, right_on="player_api_id")
# /var/folders/nz/yzml0f156sl47_8h6p_8gwc40000gn/T/ipykernel_21626/3440392743.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'player_api_id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_main = df_main.merge(df_player, left_on=ap_n, right_on="player_api_id")
# /var/folders/nz/yzml0f156sl47_8h6p_8gwc40000gn/T/ipykernel_21626/3440392743.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'player_api_id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_main = df_main.merge(df_player, left_on=ap_n, right_on="player_api_id")
# /var/folders/nz/yzml0f156sl47_8h6p_8gwc40000gn/T/ipykernel_21626/3440392743.py:10: FutureWarning: Passing 'suffixes' which cause duplicate columns {'player_api_id_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_main = df_main.merge(df_player, left_on=ap_n, right_on="player_api_id")
#        id_main     season                 date  match_api_id  \
# 0          565  2010/2011  2010-11-13 00:00:00        838651
# 1          673  2010/2011  2011-02-19 00:00:00        838822
# 2          939  2011/2012  2011-08-14 00:00:00       1032714
# 3          959  2011/2012  2011-08-27 00:00:00       1032726
# 4          980  2011/2012  2011-09-17 00:00:00       1032747
# ...        ...        ...                  ...           ...
# 21369    25905  2015/2016  2016-04-20 00:00:00       1992191
# 21370    25899  2015/2016  2016-04-09 00:00:00       1992185
# 21371    25871  2015/2016  2016-02-28 00:00:00       1992157
# 21372    25843  2015/2016  2015-11-28 00:00:00       1992134
# 21373    25934  2015/2016  2016-05-11 00:00:00       1992215
#
#        home_team_api_id  away_team_api_id  home_team_goal  away_team_goal  \
# 0                  8342              9989               2               0
# 1                 10000              9989               1               1
# 2                  8203              9989               2               1
# 3                  9991              9989               1               0
# 4                  9984              9989               0               0
# ...                 ...               ...             ...             ...
# 21369              9931              7896               3               0
# 21370             10192              7896               7               0
# 21371             10190              7896               3               3
# 21372              9824              7896               1               1
# 21373             10243              7896               0               4
#
#        home_player_1  home_player_2  ...  away_player_9_height  \
# 0            37990.0        36832.0  ...                175.26
# 1            37900.0        37886.0  ...                187.96
# 2            39573.0        80184.0  ...                177.80
# 3            37854.0        37440.0  ...                177.80
# 4            36835.0        38342.0  ...                177.80
# ...              ...            ...  ...                   ...
# 21369       156175.0       458806.0  ...                172.72
# 21370       274787.0       492132.0  ...                170.18
# 21371        42231.0       678384.0  ...                182.88
# 21372        33272.0       358156.0  ...                182.88
# 21373         7621.0       121080.0  ...                170.18
#
#        away_player_9_weight  away_player_10_name  away_player_10_birthday  \
# 0                       163         Wesley Sonck      1978-08-09 00:00:00
# 1                       187         Wesley Sonck      1978-08-09 00:00:00
# 2                       176         Wesley Sonck      1978-08-09 00:00:00
# 3                       165         Peter Kovacs      1978-02-07 00:00:00
# 4                       165          Milos Maric      1982-03-05 00:00:00
# ...                     ...                  ...                      ...
# 21369                   143     Anastasios Donis      1996-08-29 00:00:00
# 21370                   139     Anastasios Donis      1996-08-29 00:00:00
# 21371                   170      Djordje Susnjar      1992-02-18 00:00:00
# 21372                   170      Djordje Susnjar      1992-02-18 00:00:00
# 21373                   139       Ezgjan Alioski      1992-02-12 00:00:00
#
#        away_player_10_height  away_player_10_weight  away_player_11_name  \
# 0                     175.26                    168    Mohamed El Gabbas
# 1                     175.26                    168    Mohamed El Gabbas
# 2                     175.26                    168    Mohamed El Gabbas
# 3                     198.12                    214    Mohamed El Gabbas
# 4                     177.80                    176    Mohamed El Gabbas
# ...                      ...                    ...                  ...
# 21369                 177.80                    163      Antonini Culina
# 21370                 177.80                    163      Antonini Culina
# 21371                 185.42                    172       Matteo Tosetti
# 21372                 185.42                    172       Matteo Tosetti
# 21373                 172.72                    143     Anastasios Donis
#
#        away_player_11_birthday  away_player_11_height  away_player_11_weight
# 0          1987-07-21 00:00:00                 177.80                    154
# 1          1987-07-21 00:00:00                 177.80                    154
# 2          1987-07-21 00:00:00                 177.80                    154
# 3          1987-07-21 00:00:00                 177.80                    154
# 4          1987-07-21 00:00:00                 177.80                    154
# ...                        ...                    ...                    ...
# 21369      1992-01-27 00:00:00                 182.88                    170
# 21370      1992-01-27 00:00:00                 182.88                    170
# 21371      1992-02-15 00:00:00                 177.80                    154
# 21372      1992-02-15 00:00:00                 177.80                    154
# 21373      1996-08-29 00:00:00                 177.80                    163
#
# [21374 rows x 118 columns]

# %%
pd.options.display.max_columns = None

# %% [markdown]
# ## Merging Overall_rating into main DataFrame

# %%
no_nans = df_main[~df_main.isnull().any(axis=1)]
print(no_nans.shape)
no_nans.tail()
# Out:
# (21374, 140)
#        id_main     season                 date  match_api_id  \
# 21369    25905  2015/2016  2016-04-20 00:00:00       1992191
# 21370    25899  2015/2016  2016-04-09 00:00:00       1992185
# 21371    25871  2015/2016  2016-02-28 00:00:00       1992157
# 21372    25843  2015/2016  2015-11-28 00:00:00       1992134
# 21373    25934  2015/2016  2016-05-11 00:00:00       1992215
#
#        home_team_api_id  away_team_api_id  home_team_goal  away_team_goal  \
# 21369              9931              7896               3               0
# 21370             10192              7896               7               0
# 21371             10190              7896               3               3
# 21372              9824              7896               1               1
# 21373             10243              7896               0               4
#
#        home_player_1  home_player_2  home_player_3  home_player_4  \
# 21369       156175.0       458806.0        22834.0        30492.0
# 21370       274787.0       492132.0        25815.0        36785.0
# 21371        42231.0       678384.0       638592.0       413155.0
# 21372        33272.0       358156.0        41621.0       257845.0
# 21373         7621.0       121080.0        34268.0       115700.0
#
#        home_player_5  home_player_6  home_player_7  home_player_8  \
# 21369       181211.0       438780.0       207234.0       384376.0
# 21370        94553.0       147959.0       320184.0       119702.0
# 21371       210423.0        45780.0       566785.0       176298.0
# 21372       488297.0       114011.0        42237.0        56868.0
# 21373       451982.0       198082.0        41116.0       113235.0
#
#        home_player_9  home_player_10  home_player_11  away_player_1  \
# 21369        34035.0         25794.0        527103.0       330458.0
# 21370        45174.0        302079.0         37554.0        41975.0
# 21371       119839.0         35831.0        278917.0        41975.0
# 21372        32343.0        301167.0        493418.0        41975.0
# 21373       540230.0        656668.0          3517.0       330458.0
#
#        away_player_2  away_player_3  away_player_4  away_player_5  \
# 21369       282287.0       173534.0        41415.0       114212.0
# 21370         8881.0       173534.0       429986.0       282287.0
# 21371       282287.0       429986.0        41415.0       114212.0
# 21372       282287.0       173534.0        41415.0       114212.0
# 21373         8881.0       173534.0        41415.0       282287.0
#
#        away_player_6  away_player_7  away_player_8  away_player_9  \
# 21369       491221.0       393337.0         8893.0       406283.0
# 21370       491221.0       393337.0         8893.0       178142.0
# 21371         8893.0       393337.0       340790.0       186948.0
# 21372       491221.0       393337.0         8893.0       186948.0
# 21373       491221.0       393337.0         8893.0       178142.0
#
#        away_player_10  away_player_11  player_api_id_x home_player_1_name  \
# 21369        614454.0        186948.0           156175       Tomas Vaclik
# 21370        614454.0        186948.0           274787         Yvon Mvogo
# 21371        198500.0        140490.0            42231       Daniel Lopar
# 21372        198500.0        140490.0            33272        Peter Jehle
# 21373        406283.0        614454.0             7621      Anthony Favre
#
#       home_player_1_birthday  home_player_1_height  home_player_1_weight  \
# 21369    1989-03-29 00:00:00                187.96                   187
# 21370    1994-06-06 00:00:00                187.96                   185
# 21371    1985-04-19 00:00:00                187.96                   187
# 21372    1982-01-22 00:00:00                187.96                   176
# 21373    1984-02-01 00:00:00                193.04                   198
#
#        player_api_id_y   home_player_2_name home_player_2_birthday  \
# 21369           458806          Naser Aliji    1993-12-27 00:00:00
# 21370           492132  Florent Hadergjonaj    1994-07-31 00:00:00
# 21371           678384         Silvan Hefti    1997-10-25 00:00:00
# 21372           358156        Joel Untersee    1994-02-11 00:00:00
# 21373           121080        Philippe Koch    1991-02-08 00:00:00
#
#        home_player_2_height  home_player_2_weight  player_api_id_x  \
# 21369                177.80                   161            22834
# 21370                182.88                   159            25815
# 21371                182.88                   172           638592
# 21372                177.80                   163            41621
# 21373                180.34                   168            34268
#
#       home_player_3_name home_player_3_birthday  home_player_3_height  \
# 21369        Marek Suchy    1988-03-29 00:00:00                182.88
# 21370   Steve von Bergen    1983-06-10 00:00:00                182.88
# 21371          Roy Gelmi    1995-03-01 00:00:00                187.96
# 21372      Simone Grippo    1988-12-12 00:00:00                187.96
# 21373          Alain Nef    1982-02-06 00:00:00                190.50
#
#        home_player_3_weight  player_api_id_y home_player_4_name  \
# 21369                   168            30492      Walter Samuel
# 21370                   174            36785       Alain Rochat
# 21371                   172           413155       Martin Angha
# 21372                   181           257845      Mario Buehler
# 21373                   194           115700   Leonardo Sanchez
#
#       home_player_4_birthday  home_player_4_height  home_player_4_weight  \
# 21369    1978-03-23 00:00:00                182.88                   179
# 21370    1983-02-01 00:00:00                182.88                   172
# 21371    1994-01-22 00:00:00                187.96                   174
# 21372    1992-02-05 00:00:00                190.50                   172
# 21373    1986-08-02 00:00:00                190.50                   187
#
#        player_api_id_x home_player_5_name home_player_5_birthday  \
# 21369           181211       Adama Traore    1990-02-03 00:00:00
# 21370            94553        Jan Lecjaks    1990-08-09 00:00:00
# 21371           210423      Florent Hanin    1990-02-04 00:00:00
# 21372           488297      Axel Borgmann    1994-07-08 00:00:00
# 21373           451982     Cedric Brunner    1994-02-17 00:00:00
#
#        home_player_5_height  home_player_5_weight  player_api_id_y  \
# 21369                170.18                   161           438780
# 21370                185.42                   179           147959
# 21371                177.80                   165            45780
# 21372                177.80                   165           114011
# 21373                180.34                   163           198082
#
#         home_player_6_name home_player_6_birthday  home_player_6_height  \
# 21369   Alexander Fransson    1994-04-02 00:00:00                180.34
# 21370          Yoric Ravet    1989-09-12 00:00:00                177.80
# 21371         Mario Mutsch    1984-09-03 00:00:00                175.26
# 21372  Stjepan Kukuruzovic    1989-06-07 00:00:00                180.34
# 21373          Oliver Buff    1992-08-03 00:00:00                175.26
#
#        home_player_6_weight  player_api_id_x home_player_7_name  \
# 21369                   163           207234      Taulant Xhaka
# 21370                   163           320184   Leonardo Bertone
# 21371                   163           566785   Gianluca Gaudino
# 21372                   168            42237  Philipp Muntwiler
# 21373                   150            41116        Gilles Yapi
#
#       home_player_7_birthday  home_player_7_height  home_player_7_weight  \
# 21369    1991-03-28 00:00:00                172.72                   159
# 21370    1994-03-14 00:00:00                177.80                   159
# 21371    1996-11-11 00:00:00                175.26                   143
# 21372    1987-02-25 00:00:00                182.88                   176
# 21373    1982-01-30 00:00:00                170.18                   139
#
#        player_api_id_y home_player_8_name home_player_8_birthday  \
# 21369           384376     Renato Steffen    1991-11-03 00:00:00
# 21370           119702        Milan Gajic    1986-11-17 00:00:00
# 21371           176298      Marco Aratore    1991-06-04 00:00:00
# 21372            56868      Diego Ciccone    1987-07-21 00:00:00
# 21373           113235       Burim Kukeli    1984-01-16 00:00:00
#
#        home_player_8_height  home_player_8_weight  player_api_id_x  \
# 21369                170.18                   150            34035
# 21370                182.88                   168            45174
# 21371                177.80                   134           119839
# 21372                172.72                   163            32343
# 21373                180.34                   159           540230
#
#           home_player_9_name home_player_9_birthday  home_player_9_height  \
# 21369  Matias Emilio Delgado    1982-12-15 00:00:00                182.88
# 21370      Miralem Sulejmani    1988-12-05 00:00:00                177.80
# 21371        Danijel Aleksic    1991-04-30 00:00:00                182.88
# 21372         Markus Neumayr    1986-03-26 00:00:00                170.18
# 21373         Artem Simonyan    1995-02-20 00:00:00                177.80
#
#        home_player_9_weight  player_api_id_y home_player_10_name  \
# 21369                   174            25794        Davide Calla
# 21370                   170           302079           Yuya Kubo
# 21371                   165            35831      Albert Bunjaku
# 21372                   170           301167     Mauro Caballero
# 21373                   154           656668          Anto Grgic
#
#       home_player_10_birthday  home_player_10_height  home_player_10_weight  \
# 21369     1984-10-06 00:00:00                 175.26                    174
# 21370     1993-12-24 00:00:00                 177.80                    159
# 21371     1983-11-29 00:00:00                 177.80                    165
# 21372     1994-10-08 00:00:00                 175.26                    143
# 21373     1996-11-28 00:00:00                 187.96                    172
#
#        player_api_id_x home_player_11_name home_player_11_birthday  \
# 21369           527103        Breel Embolo     1997-02-14 00:00:00
# 21370            37554    Guillaume Hoarau     1984-03-05 00:00:00
# 21371           278917         Edgar Salli     1992-08-17 00:00:00
# 21372           493418      Albion Avdijaj     1994-01-12 00:00:00
# 21373             3517  Alexandr Kerzhakov     1982-11-27 00:00:00
#
#        home_player_11_height  home_player_11_weight  player_api_id_y  \
# 21369                 185.42                    185           330458
# 21370                 193.04                    176            41975
# 21371                 162.56                    141            41975
# 21372                 190.50                    176            41975
# 21373                 175.26                    168           330458
#
#       away_player_1_name away_player_1_birthday  away_player_1_height  \
# 21369        Mirko Salvi    1994-02-14 00:00:00                187.96
# 21370     Alex Valentini    1988-04-05 00:00:00                185.42
# 21371     Alex Valentini    1988-04-05 00:00:00                185.42
# 21372     Alex Valentini    1988-04-05 00:00:00                185.42
# 21373        Mirko Salvi    1994-02-14 00:00:00                187.96
#
#        away_player_1_weight  player_api_id_x away_player_2_name  \
# 21369                   176           282287    Frederic Veseli
# 21370                   176             8881     Marco Padalino
# 21371                   176           282287    Frederic Veseli
# 21372                   176           282287    Frederic Veseli
# 21373                   176             8881     Marco Padalino
#
#       away_player_2_birthday  away_player_2_height  away_player_2_weight  \
# 21369    1992-11-20 00:00:00                182.88                   176
# 21370    1983-12-08 00:00:00                177.80                   168
# 21371    1992-11-20 00:00:00                182.88                   176
# 21372    1992-11-20 00:00:00                182.88                   176
# 21373    1983-12-08 00:00:00                177.80                   168
#
#        player_api_id_y away_player_3_name away_player_3_birthday  \
# 21369           173534      Niko Datkovic    1993-04-21 00:00:00
# 21370           173534      Niko Datkovic    1993-04-21 00:00:00
# 21371           429986     Matias Malvino    1992-01-20 00:00:00
# 21372           173534      Niko Datkovic    1993-04-21 00:00:00
# 21373           173534      Niko Datkovic    1993-04-21 00:00:00
#
#        away_player_3_height  away_player_3_weight  player_api_id_x  \
# 21369                190.50                   190            41415
# 21370                190.50                   190           429986
# 21371                187.96                   174            41415
# 21372                190.50                   190            41415
# 21373                190.50                   190            41415
#
#       away_player_4_name away_player_4_birthday  away_player_4_height  \
# 21369     Orlando Urbano    1984-06-09 00:00:00                182.88
# 21370     Matias Malvino    1992-01-20 00:00:00                187.96
# 21371     Orlando Urbano    1984-06-09 00:00:00                182.88
# 21372     Orlando Urbano    1984-06-09 00:00:00                182.88
# 21373     Orlando Urbano    1984-06-09 00:00:00                182.88
#
#        away_player_4_weight  player_api_id_y away_player_5_name  \
# 21369                   174           114212    Goran Jozinovic
# 21370                   174           282287    Frederic Veseli
# 21371                   174           114212    Goran Jozinovic
# 21372                   174           114212    Goran Jozinovic
# 21373                   174           282287    Frederic Veseli
#
#       away_player_5_birthday  away_player_5_height  away_player_5_weight  \
# 21369    1990-08-27 00:00:00                177.80                   163
# 21370    1992-11-20 00:00:00                182.88                   176
# 21371    1990-08-27 00:00:00                177.80                   163
# 21372    1990-08-27 00:00:00                177.80                   163
# 21373    1992-11-20 00:00:00                182.88                   176
#
#        player_api_id_x away_player_6_name away_player_6_birthday  \
# 21369           491221  Mario Piccinocchi    1995-02-21 00:00:00
# 21370           491221  Mario Piccinocchi    1995-02-21 00:00:00
# 21371             8893        Antoine Rey    1986-08-25 00:00:00
# 21372           491221  Mario Piccinocchi    1995-02-21 00:00:00
# 21373           491221  Mario Piccinocchi    1995-02-21 00:00:00
#
#        away_player_6_height  away_player_6_weight  player_api_id_y  \
# 21369                172.72                   148           393337
# 21370                172.72                   148           393337
# 21371                167.64                   148           393337
# 21372                172.72                   148           393337
# 21373                172.72                   148           393337
#
#        away_player_7_name away_player_7_birthday  away_player_7_height  \
# 21369  Jonathan Sabbatini    1988-03-31 00:00:00                175.26
# 21370  Jonathan Sabbatini    1988-03-31 00:00:00                175.26
# 21371  Jonathan Sabbatini    1988-03-31 00:00:00                175.26
# 21372  Jonathan Sabbatini    1988-03-31 00:00:00                175.26
# 21373  Jonathan Sabbatini    1988-03-31 00:00:00                175.26
#
#        away_player_7_weight  player_api_id_x away_player_8_name  \
# 21369                   157             8893        Antoine Rey
# 21370                   157             8893        Antoine Rey
# 21371                   157           340790      Domen Crnigoj
# 21372                   157             8893        Antoine Rey
# 21373                   157             8893        Antoine Rey
#
#       away_player_8_birthday  away_player_8_height  away_player_8_weight  \
# 21369    1986-08-25 00:00:00                167.64                   148
# 21370    1986-08-25 00:00:00                167.64                   148
# 21371    1995-11-18 00:00:00                185.42                   176
# 21372    1986-08-25 00:00:00                167.64                   148
# 21373    1986-08-25 00:00:00                167.64                   148
#
#        player_api_id_y away_player_9_name away_player_9_birthday  \
# 21369           406283     Ezgjan Alioski    1992-02-12 00:00:00
# 21370           178142     Mattia Bottani    1991-05-24 00:00:00
# 21371           186948    Antonini Culina    1992-01-27 00:00:00
# 21372           186948    Antonini Culina    1992-01-27 00:00:00
# 21373           178142     Mattia Bottani    1991-05-24 00:00:00
#
#        away_player_9_height  away_player_9_weight  player_api_id_x  \
# 21369                172.72                   143           614454
# 21370                170.18                   139           614454
# 21371                182.88                   170           198500
# 21372                182.88                   170           198500
# 21373                170.18                   139           406283
#
#       away_player_10_name away_player_10_birthday  away_player_10_height  \
# 21369    Anastasios Donis     1996-08-29 00:00:00                 177.80
# 21370    Anastasios Donis     1996-08-29 00:00:00                 177.80
# 21371     Djordje Susnjar     1992-02-18 00:00:00                 185.42
# 21372     Djordje Susnjar     1992-02-18 00:00:00                 185.42
# 21373      Ezgjan Alioski     1992-02-12 00:00:00                 172.72
#
#        away_player_10_weight  player_api_id_y away_player_11_name  \
# 21369                    163           186948     Antonini Culina
# 21370                    163           186948     Antonini Culina
# 21371                    172           140490      Matteo Tosetti
# 21372                    172           140490      Matteo Tosetti
# 21373                    143           614454    Anastasios Donis
#
#       away_player_11_birthday  away_player_11_height  away_player_11_weight
# 21369     1992-01-27 00:00:00                 182.88                    170
# 21370     1992-01-27 00:00:00                 182.88                    170
# 21371     1992-02-15 00:00:00                 177.80                    154
# 21372     1992-02-15 00:00:00                 177.80                    154
# 21373     1996-08-29 00:00:00                 177.80                    163

# %% [markdown]
# ## Most recent rating for each player on match

# %%
# dropped null values from the dataframe
df_main_nn = no_nans
pd.options.display.max_columns = None

# %%
# Ratings for home players
hp = 'home_player_'
ap = 'away_player_'
start_time = time.time()
for i in range(1, 12):
    hp_n = hp+str(i)
    ap_n = ap+str(i)
    hp_n_rating = hp_n+"_rating"
    ap_n_rating = ap_n+"_rating"
    for index, row in df_main_nn.iterrows():
        df_main_nn.at[index, hp_n_rating] = mostRecentRating(dict_player_attr[row[hp_n]], row['date'])
        df_main_nn.at[index, ap_n_rating] = mostRecentRating(dict_player_attr[row[ap_n]], row['date'])
  
end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time:.4f} seconds")
# print(df_main_nn.tail())
# Out:
# Elapsed time: 624.0829 seconds

# %%
curr_date = date.today().strftime('%Y-%m-%d')
pickle_file = 'sa-preprocessing-' + curr_date + '.pkl'
pickle_file_path = 'data/' + pickle_file
df_main_nn.to_pickle(pickle_file_path)
print('Saved dataframe into .pkl file')
# Out:
# Saved dataframe into .pkl file
